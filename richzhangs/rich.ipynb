# %%
from datetime import *
from dash import *
import pandas as pd
import yfinance as yf
import numpy as np

# %%
baba = yf.Ticker("baba")

# %%
baba.info
# Out:
# {'zip': '311121',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 254702,
#  'longBusinessSummary': "Alibaba Group Holding Limited, through its subsidiaries, provides technology infrastructure and marketing reach to merchants, brands, retailers, and other businesses to engage with their users and customers in the People's Republic of China and internationally. It operates through four segments: Core Commerce, Cloud Computing, Digital Media and Entertainment, and Innovation Initiatives and Others. The company operates Taobao Marketplace, a social commerce platform; Tmall, a third-party online and mobile commerce platform for brands and retailers; Alimama, a monetization platform; 1688.com and Alibaba.com, which are online wholesale marketplaces; AliExpress, a retail marketplace; Lazada, Trendyol, and Daraz that are e-commerce platforms; and Tmall Global and Kaola, which are import e-commerce platforms. It also operates Lingshoutong that connects FMCG manufacturers and their distributors to small retailers; Cainiao Network logistic services platform; Ele.me, an on-demand delivery and local services platform; Koubei, a restaurant and local services guide platform; and Fliggy, an online travel platform. In addition, the company offers pay-for-performance, in-feed, and display marketing services; and Taobao Ad Network and Exchange, a real-time online bidding marketing exchange. Further, it provides elastic computing, database, storage, virtualization network, large-scale computing, security, management and application, big data analytics, machine learning platform, and Internet of Things services. Additionally, the company operates Youku, an online video platform; Alibaba Pictures and other content platforms that provide online videos, films, live events, news feeds, literature, music, and others; Amap, a mobile digital map, navigation, and real-time traffic information app; DingTalk, a business efficiency app; and Tmall Genie, an AI-enabled smart speaker. The company was incorporated in 1999 and is based in Hangzhou, the People's Republic of China.",
#  'city': 'Hangzhou',
#  'phone': '86 571 8502 2088',
#  'country': 'China',
#  'companyOfficers': [],
#  'website': 'http://www.alibabagroup.com',
#  'maxAge': 1,
#  'address1': '969 West Wen Yi Road',
#  'fax': '86 571 8526 9066',
#  'industry': 'Internet Retail',
#  'address2': 'Yu Hang District',
#  'ebitdaMargins': 0.20039,
#  'profitMargins': 0.19253,
#  'grossMargins': 0.40322,
#  'operatingCashflow': 215290003456,
#  'revenueGrowth': 0.338,
#  'operatingMargins': 0.13745,
#  'ebitda': 154157006848,
#  'targetLowPrice': 135,
#  'recommendationKey': 'buy',
#  'grossProfits': 297772000000,
#  'freeCashflow': 155944501248,
#  'targetMedianPrice': 242.2,
#  'currentPrice': 166.81,
#  'earningsGrowth': -0.056,
#  'currentRatio': 1.758,
#  'returnOnAssets': 0.04285,
#  'numberOfAnalystOpinions': 47,
#  'targetMeanPrice': 243.18,
#  'debtToEquity': 16.324,
#  'returnOnEquity': 0.13755,
#  'targetHighPrice': 336.01,
#  'totalCash': 483351986176,
#  'totalDebt': 181240004608,
#  'totalRevenue': 769278017536,
#  'totalCashPerShare': 177.752,
#  'financialCurrency': 'CNY',
#  'revenuePerShare': 284.099,
#  'quickRatio': 1.313,
#  'recommendationMean': 1.8,
#  'exchange': 'NYQ',
#  'shortName': 'Alibaba Group Holding Limited',
#  'longName': 'Alibaba Group Holding Limited',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'EQUITY',
#  'symbol': 'BABA',
#  'messageBoardId': 'finmb_42083601',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 0.372,
#  'beta3Year': None,
#  'enterpriseToEbitda': 1.857,
#  '52WeekChange': -0.35422552,
#  'morningStarRiskRating': None,
#  'forwardEps': 10.78,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 2710909952,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 358.74,
#  'sharesShort': 47045938,
#  'sharesPercentSharesOut': 0.0174,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1617148800,
#  'heldPercentInstitutions': 0.25779,
#  'netIncomeToCommon': 147857997824,
#  'trailingEps': 8.394,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.29114044,
#  'priceToBook': 0.4649886,
#  'heldPercentInsiders': 0.26214,
#  'nextFiscalYearEnd': 1680220800,
#  'yield': None,
#  'mostRecentQuarter': 1625011200,
#  'shortRatio': 2.14,
#  'sharesShortPreviousMonthDate': 1632960000,
#  'floatShares': 1937030545,
#  'beta': 0.85922,
#  'enterpriseValue': 286237097984,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'lastDividendDate': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': -0.052,
#  'priceToSalesTrailing12Months': 0.58783287,
#  'dateShortInterest': 1635465600,
#  'pegRatio': 70.83,
#  'ytdReturn': None,
#  'forwardPE': 15.474026,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': 71128648,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 167.85,
#  'regularMarketOpen': 165.1735,
#  'twoHundredDayAverage': 189.93141,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': 0,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 167.8,
#  'navPrice': None,
#  'averageDailyVolume10Day': 16278525,
#  'regularMarketPreviousClose': 167.85,
#  'fiftyDayAverage': 161.97362,
#  'trailingAnnualDividendRate': None,
#  'open': 165.1735,
#  'toCurrency': None,
#  'averageVolume10days': 16278525,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 163.4,
#  'currency': 'USD',
#  'trailingPE': 19.872528,
#  'regularMarketVolume': 13720010,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 452206886912,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 25372821,
#  'dayLow': 163.4,
#  'ask': 167.27,
#  'askSize': 1400,
#  'volume': 13720010,
#  'fiftyTwoWeekHigh': 280.61,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 138.43,
#  'bid': 167.06,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 1200,
#  'dayHigh': 167.8,
#  'regularMarketPrice': 166.81,
#  'logo_url': 'https://logo.clearbit.com/alibabagroup.com'}

# %%
start = "2017-01-01"
end = "2021-01-01"
size = 1007
short_term = 3
long_term_one = 30
long_term_two = 45
long_term_three = 60
default_nan = np.nan
day = 1
week = 5
month = 20
win_ratio = 1.05
loss_ratio = 0.95

# %%
def getTickers():
    ticker_files = pd.read_csv("../pre_loaded_files/tickers_availables.csv")
    return ticker_files

# %%
ticker_names = getTickers()

# %%
ticker_names
# Out:
#       Unnamed: 0 Symbol                                 Industry
# 0              0      A           Life Sciences Tools & Services
# 1              1     AA                          Metals & Mining
# 2              2   AAIC  Mortgage Real Estate Investment Trus...
# 3              3    AAL                                 Airlines
# 4              4   AAOI                 Communications Equipment
# ...          ...    ...                                      ...
# 3313        3313    ZTO                  Air Freight & Logistics
# 3314        3314    ZTS                          Pharmaceuticals
# 3315        3315   ZUMZ                         Specialty Retail
# 3316        3316    ZWS                Utilities-Regulated Water
# 3317        3317   ZYNE                          Pharmaceuticals
#
# [3318 rows x 3 columns]

# %%
for i in range(len(ticker_names)):
    if "..." in ticker_names.loc[i]['Industry']:
        ticker_names.loc[i]['Industry'] = yf.Ticker(ticker_names.loc[i]["Symbol"]).info['industry']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/series.py:1056: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cacher_needs_updating = self._check_is_chained_assignment_possible()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/qb/zkr1kmzd3dqb3n6902fws8gw0000gn/T/ipykernel_6188/2051307969.py in <module>
#       1 for i in range(len(ticker_names)):
# ----> 2     if "..." in ticker_names.loc[i]['Industry']:
#       3         ticker_names.loc[i]['Industry'] = yf.Ticker(ticker_names.loc[i]["Symbol"]).info['industry']
#
# TypeError: argument of type 'float' is not iterable

# %%
ticker_names.to_csv("../pre_loaded_files/tickers_availables.csv")

# %%
# for i in range(0, len(ticker_names)):
#     ticker_symbol = ticker_names.iloc[i]['Symbol']
#     print(i)
#     try:      
#         ticker = yf.Ticker(ticker_symbol)
#         ticker_history = ticker.history(start=start, end=end)
#         ticker_industry = ticker.info['industry']
#         if len(ticker_history) == size:
#             success.append(i)
#             ticker_available.loc[len(ticker_available.index)] = [ticker_symbol, ticker_industry]
#             ticker_history = ticker_history.drop(columns = ['Dividends','Stock Splits'])
#             ticker_history["Time"] = ticker_history.index.view(np.int64) / 1000000000
#             ticker_history = ticker_history.astype({"Time": int})
#             ticker_history = ticker_history.round({'Open': 2, 'Close': 2, 'High': 2, 'Low': 2})
#             ticker_history = ticker_history.set_index("Time", append=True)
#             ticker_history.to_csv("../tickers_history/" + ticker_symbol + ".csv")
#         else:
#             fail.append(i)
#     except:
#         wrongList.append(i)
#         wrongName.append(ticker_symbol)

# %%
# Out:
# Empty DataFrame
# Columns: [Symbol, Industry]
# Index: []
